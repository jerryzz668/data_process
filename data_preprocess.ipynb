# %%
# -*- coding: utf-8 -*-
"""
Created on Aug 2 2021

@author: Administrator @ Zepeng Li
"""
import pandas as pd
import numpy as np
import os

# %%
path = os.getcwd()

# %%
#对文件夹所有csv进行合并
def concat_csv(csv_folder_path):
    data_dict = dict()
    data_dict_value = dict()
    df = pd.DataFrame()
    dl = list()
    for csv_file in os.listdir(csv_folder_path):
        data_dict['%s'%csv_file] = pd.read_csv(os.path.join(csv_folder_path,csv_file))[['y','x']]
        data_dict_value['%s'%csv_file] = pd.read_csv(os.path.join(csv_folder_path,csv_file)).iloc[0,3]
        dl.append(data_dict_value['%s'%csv_file])
        data_dict['%s'%csv_file].insert(0,'ID','{}_{}'.format(os.path.basename(csv_folder_path), os.path.splitext(csv_file)[0]))
        data_dict['%s'%csv_file].insert(3,'value',data_dict_value['%s'%csv_file])
        df = df.append(data_dict['%s'%csv_file])
    return df,dl

# %%
#数据concat
csv_folder_path = '/home/jerry/Documents/IIAC_data'
df,dl= concat_csv(csv_folder_path)
df
# Out:
#                  ID         y            x  value
# 0     IIAC_data_154  0.062988     0.000000  27.65
# 1     IIAC_data_154  0.055115     0.001000  27.65
# 2     IIAC_data_154  0.065613     0.000000  27.65
# 3     IIAC_data_154  0.091858    -0.001333  27.65
# 4     IIAC_data_154  0.073486    -0.002999  27.65
# ...             ...       ...          ...    ...
# 1468  IIAC_data_113 -0.031494  4669.207343  22.59
# 1469  IIAC_data_113 -0.094482  4668.496241  22.59
# 1470  IIAC_data_113 -0.060364  4667.823794  22.59
# 1471  IIAC_data_113  0.041992  4667.183002  22.59
# 1472  IIAC_data_113  0.065613  4666.590862  22.59
#
# [145331 rows x 4 columns]

# %%
##打印time列
#为打时间戳，需要将结果ID单独存在一个list中，方便调用
r_list = df.keys()[0]
clo_r = df[r_list]#id列
##angle = df[df.keys()[1]]
class_l = list(set(clo_r))
#按结果ID列对整个数据框重新排序
## 设置成“category”数据类型
df['ID'] = df['ID'].astype('category')
##inplace = True，使 recorder_categories生效
df['ID'].cat.reorder_categories(class_l, inplace=True)
##inplace = True，使 df生效
df.sort_values('ID', inplace=True)
##将DataFrame中index重排
df.reset_index(drop=True, inplace=True)
#打时间戳
df_new = []
for i in class_l:
    time = list(range(1,1+df.loc[df['ID'] == i].shape[0]))
    df_new = df_new + time
df['time'] = df_new
df
# Out:
#                    ID          y            x  value  time
# 0        IIAC_data_16   0.341187   -23.430029  27.71     1
# 1        IIAC_data_16   0.440918  3395.051671  27.71     2
# 2        IIAC_data_16   0.325439    91.056319  27.71     3
# 3        IIAC_data_16   0.593140   127.541759  27.71     4
# 4        IIAC_data_16  -0.070862   144.268307  27.71     5
# ...               ...        ...          ...    ...   ...
# 145326  IIAC_data_170  22.476318  4614.964690  23.24  1456
# 145327  IIAC_data_170  22.339844  4615.431205  23.24  1457
# 145328  IIAC_data_170  22.350342  4615.904717  23.24  1458
# 145329  IIAC_data_170  21.896301  4589.224081  23.24  1459
# 145330  IIAC_data_170   0.388428   314.911684  23.24  1460
#
# [145331 rows x 5 columns]

# %%
dfs = df[['ID','y','x','time']]
dfs
# Out:
#                    ID          y            x  time
# 0        IIAC_data_16   0.341187   -23.430029     1
# 1        IIAC_data_16   0.440918  3395.051671     2
# 2        IIAC_data_16   0.325439    91.056319     3
# 3        IIAC_data_16   0.593140   127.541759     4
# 4        IIAC_data_16  -0.070862   144.268307     5
# ...               ...        ...          ...   ...
# 145326  IIAC_data_170  22.476318  4614.964690  1456
# 145327  IIAC_data_170  22.339844  4615.431205  1457
# 145328  IIAC_data_170  22.350342  4615.904717  1458
# 145329  IIAC_data_170  21.896301  4589.224081  1459
# 145330  IIAC_data_170   0.388428   314.911684  1460
#
# [145331 rows x 4 columns]

# %%
#特征提取
from tsfresh import extract_features
extracted_features = extract_features(dfs, column_id="ID", column_sort="time")
# Out:
# Feature Extraction: 100%|██████████| 29/29 [01:05<00:00,  2.27s/it]

# %%
extracted_features
# Out:
#                y__variance_larger_than_standard_deviation  \
# IIAC_data_16                                          1.0
# IIAC_data_137                                         1.0
# IIAC_data_120                                         1.0
# IIAC_data_164                                         1.0
# IIAC_data_133                                         1.0
# ...                                                   ...
# IIAC_data_145                                         1.0
# IIAC_data_103                                         1.0
# IIAC_data_123                                         1.0
# IIAC_data_156                                         1.0
# IIAC_data_170                                         1.0
#
#                y__has_duplicate_max  y__has_duplicate_min  y__has_duplicate  \
# IIAC_data_16                    0.0                   0.0               1.0
# IIAC_data_137                   0.0                   0.0               1.0
# ...

# %%
#label
dl = pd.DataFrame(dl)
dl
# Out:
#         0
# 0   27.65
# 1   23.88
# 2   22.21
# 3   28.50
# 4   23.23
# ..    ...
# 95  23.32
# 96  23.24
# 97  29.71
# 98  23.50
# 99  22.59
#
# [100 rows x 1 columns]

# %%
#xgboost
import xgboost as xgb
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import explained_variance_score
from sklearn.metrics import median_absolute_error
from xgboost import plot_importance

# 1.切分数据输入：特征 输出：预测目标变量
y = dl
# X = extracted_features.drop(['SalePrice'], axis=1).select_dtypes(exclude=['object'])
X = extracted_features
# 2.切分训练集、测试集,切分比例7.5 : 2.5
train_X, test_X, train_y, test_y = train_test_split(X.values, y.values, test_size=0.25)

# 2.空值处理，默认方法：使用特征列的平均值进行填充
my_imputer = SimpleImputer()
train_X = my_imputer.fit_transform(train_X)
test_X = my_imputer.transform(test_X)

# 4.调用XGBoost模型，使用训练集数据进行训练（拟合）
# Add verbosity=2 to print messages while running boosting
my_model = xgb.XGBRegressor(n_estimators=1000,objective='reg:squarederror', verbosity=2)
my_model.fit(train_X, train_y, verbose=False)

# 5.使用模型对测试集数据进行预测
predictions = my_model.predict(test_X)

# 6.对模型的预测结果进行评判（平均绝对误差）
y_test = list(test_y)
y_pre = list(predictions)
print("MAE : " + str(mean_absolute_error(y_test, y_pre)))
print('MSE : '+ str(mean_squared_error(y_test, y_pre)))
print('R^2 :'+ str(r2_score(y_test,y_pre)))
print('Median absolute error :' +str(median_absolute_error(y_test, y_pre)))
print('回归方差(反应自变量与因变量之间的相关程度):' + str(explained_variance_score(y_test, y_pre, sample_weight=None, multioutput='uniform_average')))
plot_importance(my_model)
plt.show()
# Out:
# [18:29:30] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [18:29:30] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [18:29:30] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [18:29:30] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [18:29:30] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [18:29:30] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [18:29:30] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=4
# [18:29:30] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=3
# ...
